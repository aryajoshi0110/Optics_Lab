# %% [markdown]
# *Name* : -
#
# *Roll No.* : -
#
# Acknowledgement :- ChatGPT was used to assist in making this journal report

# %% [markdown]
# # **Optical Spatial Filtering – Applied Fourier Optics**

# %% [markdown]
# # Aim
# To understand fundamental optics principles of Babinet’s Principle, Abbe’s Principle, Kohler illumination, Fourier transformation and its applications.

# %% [markdown]
# # Apparatus
# LED and its controller, filter, irir, lenses, target with different objects, masks slide, beam splitter, tube lens, camera, viewing screen, computer (for image analysis).

# %% [markdown]
# # Theory

# %% [markdown]
# ## Observations

# %% [markdown]
# ![alt text](Images/1_1.png)
#
# Image 1

# %% [markdown]
# ![alt text](Images/1_2.png)
#
# Image 2

# %% [markdown]
# ![alt text](Images/1_3.png)
#
# Image 3

# %% [markdown]
# ![alt text](Images/1_4.png)
#
# Image 4

# %% [markdown]
# ![alt text](Images/1_5.png)
#
# Image 5

# %% [markdown]
# ![alt text](Images/2_2i.png)
# ![alt text](Images/2_1f.jpeg)

# %% [markdown]
# ![alt text](Images/2_2i.png)
# ![alt text](Images/2_2f.jpeg)

# %% [markdown]
# ![alt text](Images/2_3i.png)
# ![alt text](Images/2_3f.jpeg)

# %% [markdown]
# ![alt text](Images/2_4i.png)
# ![alt text](Images/2_4f.jpeg)

# %% [markdown]
# ![alt text](Images/2_5i.png)
# ![alt text](Images/2_5f.jpeg)

# %% [markdown]
# ![alt text](Images/3_1.png)
# ![alt text](Images/3_1h.png)
# ![alt text](Images/3_1v.png)

# %% [markdown]
# ![alt text](Images/3_2.png)
# ![alt text](Images/3_2h.png)
# ![alt text](Images/3_2v.png)

# %% [markdown]
# ![alt text](Images/3_3.png)
# ![alt text](Images/3_3h.png)
# ![alt text](Images/3_3v.png)

# %% [markdown]
# ![alt text](Images/3_4.png)
# ![alt text](Images/3_4h.png)
# ![alt text](Images/3_4v.png)

# %% [markdown]
# ![alt text](Images/3_5.png)
# ![alt text](Images/3_5s1.png)
# ![alt text](Images/3_s2.png)
